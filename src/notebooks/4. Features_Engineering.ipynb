# %%
import pandas as pd
import numpy as np
from google.colab import files

# %%
df = pd.read_csv('../../data/proccesed/carsome_data_cleaned.csv')

# %%
df
# Out:
#       Year                      Model  Total_Price(RM)  Price_per_month(RM)  \
# 0     2017                myvi se 1.5          35400.0                406.0
# 1     2023    forester l eyesight 2.0         115800.0               1137.0
# 2     2018          jazz s i-vtec 1.5          52900.0                611.0
# 3     2016          cx-3 skyactiv 2.0          55800.0                711.0
# 4     2021                myvi av 1.5          49900.0                460.0
# ...    ...                        ...              ...                  ...
# 1831  2019  a200 progressive line 1.3         132000.0               1447.0
# 1832  2018      3 skyactiv-g high 2.0          69000.0                828.0
# 1833  2016                vios gx 1.5          50500.0                686.0
# 1834  2022   x3 xdrive30i m sport 2.0         219800.0               2409.0
# 1835  2020                myvi av 1.5          46600.0                511.0
#
#       Mileage(km) Transmission  \
# ...

# %%
numerical_col = df.select_dtypes(include=[np.number])
categorical_col = df.select_dtypes(exclude=[np.number])

# %%
def remove_outliers_iqr(df, columns):
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

df = remove_outliers_iqr(df, numerical_col)

# %%
df
# Out:
#       Year                    Model  Total_Price(RM)  Price_per_month(RM)  \
# 0     2017              myvi se 1.5          35400.0                406.0
# 1     2023  forester l eyesight 2.0         115800.0               1137.0
# 2     2018        jazz s i-vtec 1.5          52900.0                611.0
# 3     2016        cx-3 skyactiv 2.0          55800.0                711.0
# 4     2021              myvi av 1.5          49900.0                460.0
# ...    ...                      ...              ...                  ...
# 1828  2017    vios trd sportivo 1.5          53600.0                715.0
# 1830  2020                 c-hr 1.8         101800.0               1116.0
# 1832  2018    3 skyactiv-g high 2.0          69000.0                828.0
# 1833  2016              vios gx 1.5          50500.0                686.0
# 1835  2020              myvi av 1.5          46600.0                511.0
#
#       Mileage(km) Transmission  \
# 0         92189.0            A
# ...

# %%
df.to_csv('carsome_data_super_cleaned.csv', index=False)
files.download('carsome_data_super_cleaned.csv')
