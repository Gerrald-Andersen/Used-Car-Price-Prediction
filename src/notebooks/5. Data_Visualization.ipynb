# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../data/proccesed/carsome_data_super_cleaned.csv')

# %%
df
# Out:
#       Year                    Model  Total_Price(RM)  Price_per_month(RM)  \
# 0     2017              myvi se 1.5          35400.0                406.0
# 1     2023  forester l eyesight 2.0         115800.0               1137.0
# 2     2018        jazz s i-vtec 1.5          52900.0                611.0
# 3     2016        cx-3 skyactiv 2.0          55800.0                711.0
# 4     2021              myvi av 1.5          49900.0                460.0
# ...    ...                      ...              ...                  ...
# 1660  2017    vios trd sportivo 1.5          53600.0                715.0
# 1661  2020                 c-hr 1.8         101800.0               1116.0
# 1662  2018    3 skyactiv-g high 2.0          69000.0                828.0
# 1663  2016              vios gx 1.5          50500.0                686.0
# 1664  2020              myvi av 1.5          46600.0                511.0
#
#       Mileage(km) Transmission  \
# 0         92189.0            A
# 1         14200.0            A
# 2         75759.0            A
# 3         59833.0            A
# 4         69974.0            A
# ...           ...          ...
# 1660      36537.0            A
# 1661      40220.0            A
# 1662      97077.0            A
# 1663     144662.0            A
# 1664      83531.0            A
#
#                                                Location             Highlight  \
# 0     carsome showroom setia spice, pulau pinang 14,...  national daily drive
# 1     carsome pj automall, selangor 14,748.1 km\n   ...           compact suv
# 2     carsome showroom kuala terengganu, terengganu ...           daily drive
# 3     carsome showroom kota kinabalu, sabah 13,814.5...           compact suv
# 4     carsome showroom johor jaya, johor 14,832.8 km...  national daily drive
# ...                                                 ...                   ...
# 1660  carsome showroom kota kinabalu, sabah 13,814.5...           daily drive
# 1661  carsome pj automall, selangor 14,748.1 km\n   ...           compact suv
# 1662  carsome showroom kempas, johor 14,839.0 km\n  ...   upgrade daily drive
# 1663  carsome showroom setia spice, pulau pinang 14,...           daily drive
# 1664  carsome showroom kuantan avenue, pahang 14,612...  national daily drive
#
#                                                     URL    Brand
# 0     https://www.carsome.my/buy-car/perodua/myvi/20...  Perodua
# 1     https://www.carsome.my/buy-car/subaru/forester...   Subaru
# 2     https://www.carsome.my/buy-car/honda/jazz/2018...    Honda
# 3     https://www.carsome.my/buy-car/mazda/cx-3/2016...    Mazda
# 4     https://www.carsome.my/buy-car/perodua/myvi/20...  Perodua
# ...                                                 ...      ...
# 1660  https://www.carsome.my/buy-car/toyota/vios/201...   Toyota
# 1661  https://www.carsome.my/buy-car/toyota/c-hr/202...   Toyota
# 1662  https://www.carsome.my/buy-car/mazda/3/2018-ma...    Mazda
# 1663  https://www.carsome.my/buy-car/toyota/vios/201...   Toyota
# 1664  https://www.carsome.my/buy-car/perodua/myvi/20...  Perodua
#
# [1665 rows x 10 columns]

# %%
sorted = ['Year', 'Brand', 'Model', 'Mileage(km)', 'Transmission', 'Highlight', 'Location', 'Price_per_month(RM)', 'Total_Price(RM)']
df = df[sorted]

# %%
df
# Out:
#       Year    Brand                    Model  Mileage(km) Transmission  \
# 0     2017  Perodua              myvi se 1.5      92189.0            A
# 1     2023   Subaru  forester l eyesight 2.0      14200.0            A
# 2     2018    Honda        jazz s i-vtec 1.5      75759.0            A
# 3     2016    Mazda        cx-3 skyactiv 2.0      59833.0            A
# 4     2021  Perodua              myvi av 1.5      69974.0            A
# ...    ...      ...                      ...          ...          ...
# 1660  2017   Toyota    vios trd sportivo 1.5      36537.0            A
# 1661  2020   Toyota                 c-hr 1.8      40220.0            A
# 1662  2018    Mazda    3 skyactiv-g high 2.0      97077.0            A
# 1663  2016   Toyota              vios gx 1.5     144662.0            A
# 1664  2020  Perodua              myvi av 1.5      83531.0            A
#
#                  Highlight                                           Location  \
# 0     national daily drive  carsome showroom setia spice, pulau pinang 14,...
# 1              compact suv  carsome pj automall, selangor 14,748.1 km\n   ...
# 2              daily drive  carsome showroom kuala terengganu, terengganu ...
# 3              compact suv  carsome showroom kota kinabalu, sabah 13,814.5...
# 4     national daily drive  carsome showroom johor jaya, johor 14,832.8 km...
# ...                    ...                                                ...
# 1660           daily drive  carsome showroom kota kinabalu, sabah 13,814.5...
# 1661           compact suv  carsome pj automall, selangor 14,748.1 km\n   ...
# 1662   upgrade daily drive  carsome showroom kempas, johor 14,839.0 km\n  ...
# 1663           daily drive  carsome showroom setia spice, pulau pinang 14,...
# 1664  national daily drive  carsome showroom kuantan avenue, pahang 14,612...
#
#       Price_per_month(RM)  Total_Price(RM)
# 0                   406.0          35400.0
# 1                  1137.0         115800.0
# 2                   611.0          52900.0
# 3                   711.0          55800.0
# 4                   460.0          49900.0
# ...                   ...              ...
# 1660                715.0          53600.0
# 1661               1116.0         101800.0
# 1662                828.0          69000.0
# 1663                686.0          50500.0
# 1664                511.0          46600.0
#
# [1665 rows x 9 columns]

# %%
Select_Features = ['Year', 'Brand', 'Model', 'Mileage(km)', 'Transmission', 'Highlight', 'Location', 'Total_Price(RM)']
df = df[Select_Features]

# %%
df.head()
# Out:
#    Year    Brand                    Model  Mileage(km) Transmission  \
# 0  2017  Perodua              myvi se 1.5      92189.0            A
# 1  2023   Subaru  forester l eyesight 2.0      14200.0            A
# 2  2018    Honda        jazz s i-vtec 1.5      75759.0            A
# 3  2016    Mazda        cx-3 skyactiv 2.0      59833.0            A
# 4  2021  Perodua              myvi av 1.5      69974.0            A
#
#               Highlight                                           Location  \
# 0  national daily drive  carsome showroom setia spice, pulau pinang 14,...
# 1           compact suv  carsome pj automall, selangor 14,748.1 km\n   ...
# 2           daily drive  carsome showroom kuala terengganu, terengganu ...
# 3           compact suv  carsome showroom kota kinabalu, sabah 13,814.5...
# 4  national daily drive  carsome showroom johor jaya, johor 14,832.8 km...
#
#    Total_Price(RM)
# 0          35400.0
# 1         115800.0
# 2          52900.0
# 3          55800.0
# 4          49900.0

# %%
df['Location'].unique()
# Out:
# array(['carsome showroom setia spice, pulau pinang 14,555.5 km\n          away',
#        'carsome pj automall, selangor 14,748.1 km\n          away',
#        'carsome showroom kuala terengganu, terengganu 14,461.7 km\n          away',
#        'carsome showroom kota kinabalu, sabah 13,814.5 km\n          away',
#        'carsome showroom johor jaya, johor 14,832.8 km\n          away',
#        'carsome showroom seremban oakland, negeri sembilan 14,780.1 km\n          away',
#        'carsome showroom kuantan avenue, pahang 14,612.7 km\n          away',
#        'carsome showroom kuching, sarawak 14,543.4 km\n          away',
#        'carsome showroom melaka, melaka 14,822.0 km\n          away',
#        'carsome showroom kempas, johor 10,512.9 km\n          away',
#        'carsome showroom juru autocity, pulau pinang 14,549.9 km\n          away',
#        'carsome showroom chan sow lin, kuala lumpur 14,744.2 km\n          away',
#        'carsome showroom kempas, johor 14,839.0 km\n          away',
#        'carsome showroom sitiawan, perak 14,662.1 km\n          away',
#        'carsome showroom alor setar, kedah 14,468.6 km\n          away',
#        'carsome showroom kota kinabalu, sabah 10,512.9 km\n          away',
#        'carsome showroom setiawangsa, kuala lumpur 14,736.0 km\n          away',
#        'carsome showroom ipoh, perak 14,609.1 km\n          away',
#        'carsome showroom cheras, selangor 14,747.6 km\n          away',
#        'carsome showroom aeon big kepong, kuala lumpur 14,735.7 km\n          away',
#        'carsome showroom kota bharu, kelantan 14,408.9 km\n          away',
#        'carsome showroom temerloh, pahang 14,682.9 km\n          away',
#        'carsome showroom aeon big kepong, kuala lumpur 10,512.9 km\n          away',
#        'carsome showroom melaka, melaka 10,512.9 km\n          away',
#        'carsome showroom setia spice, pulau pinang 10,512.9 km\n          away'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1665 entries, 0 to 1664
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             1665 non-null   int64
#  1   Brand            1665 non-null   object
#  2   Model            1665 non-null   object
#  3   Mileage(km)      1665 non-null   float64
#  4   Transmission     1665 non-null   object
#  5   Highlight        1665 non-null   object
#  6   Location         1665 non-null   object
#  7   Total_Price(RM)  1665 non-null   float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 104.2+ KB

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1665 entries, 0 to 1664
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             1665 non-null   int64
#  1   Brand            1665 non-null   object
#  2   Model            1665 non-null   object
#  3   Mileage(km)      1665 non-null   float64
#  4   Transmission     1665 non-null   object
#  5   Highlight        1665 non-null   object
#  6   Location         1665 non-null   object
#  7   Total_Price(RM)  1665 non-null   float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 104.2+ KB

# %%
numerical_col = df.select_dtypes(include=[np.number])
categorical_col = df.select_dtypes(exclude=[np.number])

# %%
df['Year'].plot(
    kind='hist',
    color='pink',
    edgecolor='black',
    bins=5,
    figsize=(16,8)
)

plt.ticklabel_format(style='plain', axis='x')
plt.xlabel('Year', fontsize=18)
plt.ylabel('Frequency', fontsize=18)
plt.title('Distribution of Year', fontdict={'fontsize': 24})
plt.grid(True)
plt.show()

# %%
df.groupby('Brand').size().plot.bar(figsize=(16, 8))
plt.title('Distribution of Car Brand', fontsize=20)
plt.xlabel('Brand', fontsize=14)
plt.ylabel('Jumlah', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.groupby('Model').size().plot.bar(figsize=(16, 8))
plt.title('Distribution of Car Model', fontsize=20)
plt.xlabel('Model', fontsize=14)
plt.ylabel('Jumlah', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['Mileage(km)'].plot(
    kind='hist',
    color='pink',
    edgecolor='black',
    bins=5,
    figsize=(16,8)
)

plt.ticklabel_format(style='plain', axis='x')
plt.xlabel('Mileage (km)', fontsize=18)
plt.ylabel('Frequency', fontsize=18)
plt.title('Distribution of Mileage', fontdict={'fontsize': 24})
plt.grid(True)
plt.show()

# %%
df['Transmission'].value_counts().plot(kind='pie', label='', legend=True, autopct='%1.1f%%', figsize=(14,10))
plt.title("Percentage of Transmission", fontdict={'fontsize': 24})
plt.show()

# %%
df.groupby('Location').size().plot.bar(figsize=(16, 8))
plt.title('Distribution Location', fontsize=20)
plt.xlabel('Location', fontsize=14)
plt.ylabel('Jumlah', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['Total_Price(RM)'].plot(
    kind='hist',
    color='pink',
    edgecolor='black',
    bins=5,
    figsize=(16,8)
)

plt.ticklabel_format(style='plain', axis='x')
plt.xlabel('Total Price (RM)', fontsize=18)
plt.ylabel('Frequency', fontsize=18)
plt.title('Distribution of Car Total Price', fontdict={'fontsize': 24})
plt.grid(True)
plt.show()

# %%
# Buat daftar kolom numerik manual atau otomatis
numerical_col = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Sekarang plot boxplot
df[numerical_col].plot(
    kind='box',
    subplots=True,
    layout=(1, len(numerical_col)),
    sharex=False,
    sharey=False,
    figsize=(20, 6),
    color='blue'
)

plt.tight_layout()
plt.show()
